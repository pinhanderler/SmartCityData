# %% [markdown]
# # Notebook Config

# %%
# ===============================
# RESOURCES & CONFIG
# ===============================

from datetime import datetime, timezone, timedelta

# -------------------------------
# DATE
# -------------------------------
TODAY = datetime.now(timezone.utc).strftime("%Y-%m-%d")

# -------------------------------
# ROOT PATH (Lakehouse kökü)
# -------------------------------
ROOT_PATH = "abfss://e5c59b1a-f845-4467-b859-d65a059702db@onelake.dfs.fabric.microsoft.com/4ed0e237-04d9-4f52-be5a-2fa5b9fb7c8a"


# -------------------------------
# BASE FILE PATH
# -------------------------------
BASE_PATH = f"{ROOT_PATH}/Files"

# -------------------------------
# LAYER PATHS
# -------------------------------
BRONZE_PATH = f"{BASE_PATH}/bronze"
SILVER_PATH = f"{BASE_PATH}/silver"
GOLD_PATH   = f"{BASE_PATH}/gold"

# -------------------------------
# DATASET PATHS (Metadata Driven)
# -------------------------------
#TODAY = "2025-12-21"
PATHS = {
    # BRONZE
    "weather_bronze": f"{BRONZE_PATH}/weather/{TODAY}.json",
    "air_bronze":     f"{BRONZE_PATH}/air_quality/{TODAY}.json",
    "energy_bronze":  f"{BRONZE_PATH}/energy_prices/{TODAY}.json",

    # SILVER
    "weather_silver": f"{SILVER_PATH}/weather",
    "air_silver":     f"{SILVER_PATH}/air_quality",
    "energy_silver":  f"{SILVER_PATH}/energy_prices",

    # GOLD
    "weather_gold": f"{GOLD_PATH}/weather",
    "air_gold":     f"{GOLD_PATH}/air_quality",
    "energy_gold":  f"{GOLD_PATH}/energy_prices",
}

print("Config Loaded")
# Out:
# StatementMeta(, af15b433-4e88-4c11-ad20-0d2416dd34b6, 5, Finished, Available, Finished)
# Config Loaded
